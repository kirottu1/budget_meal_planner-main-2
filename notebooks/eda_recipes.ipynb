# %%
import pandas as pd

# %%
recipes_df = pd.read_csv("../data/recipes/RAW_recipes.csv")

# %%
print('The recipes dataset has', recipes_df['id'].nunique(), 'unique recipes.')

# %%
recipes_df = recipes_df.drop_duplicates(subset='id')


recipes_df['nutrition'] = recipes_df['nutrition'].apply(eval)

nutrition_columns = ['calories', 'total fat (PDV)', 'sugar (PDV)', 'sodium (PDV)', 'protein (PDV)', 'saturated fat (PDV)', 'carbohydrates (PDV)']
recipes_df[nutrition_columns] = pd.DataFrame(recipes_df['nutrition'].tolist(), index = recipes_df.index)

recipes_df = recipes_df.drop(['nutrition'], axis=1)

recipes_df = recipes_df.drop_duplicates()


recipes_df = recipes_df[(recipes_df['calories'] != 0) &
                                          (recipes_df['minutes'] != 0) &
                                          (recipes_df['n_steps'] != 0)]

# %%
recipes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230489 entries, 0 to 231636
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   name                 230488 non-null  object
#  1   id                   230489 non-null  int64
#  2   minutes              230489 non-null  int64
#  3   contributor_id       230489 non-null  int64
#  4   submitted            230489 non-null  object
#  5   tags                 230489 non-null  object
#  6   n_steps              230489 non-null  int64
#  7   steps                230489 non-null  object
#  8   description          226175 non-null  object
#  9   ingredients          230489 non-null  object
#  10  n_ingredients        230489 non-null  int64
#  11  calories             230489 non-null  float64
#  12  total fat (PDV)      230489 non-null  float64
#  13  sugar (PDV)          230489 non-null  float64
#  14  sodium (PDV)         230489 non-null  float64
# ...

# %%
null_values = recipes_df.isnull().sum()
print(null_values)
# Out:
# name                      1
# id                        0
# minutes                   0
# contributor_id            0
# submitted                 0
# tags                      0
# n_steps                   0
# steps                     0
# description            4314
# ingredients               0
# n_ingredients             0
# calories                  0
# total fat (PDV)           0
# sugar (PDV)               0
# sodium (PDV)              0
# protein (PDV)             0
# saturated fat (PDV)       0
# carbohydrates (PDV)       0
# dtype: int64

# %%
recipes_df[recipes_df['name'].isnull()]['tags'].values
# Out:
# array([], dtype=object)

# %%
recipes_df[recipes_df['name'].isnull()]['ingredients'].values

# %%
recipes_df[recipes_df['name'].isnull()]['id'].values

# %%
recipes_df.loc[(recipes_df['name'].isnull()) & (recipes_df["id"]== 368257 ), 'name'] = "salad-dressings"

# %%
recipes_df[recipes_df["id"]== 368257]
# Out:
#                 name      id  minutes  contributor_id   submitted  \
# 721  salad-dressings  368257       10          779451  2009-04-27
#
#                                                   tags  n_steps  \
# 721  ['15-minutes-or-less', 'time-to-make', 'course...        6
#
#                                                  steps    description  \
# 721  ['in a bowl , combine ingredients except for o...  -------------
#
#                                            ingredients  n_ingredients  \
# 721  ['lemon', 'honey', 'horseradish mustard', 'gar...             10
#
#      calories  total fat (PDV)  sugar (PDV)  sodium (PDV)  protein (PDV)  \
# 721    1596.2            249.0        155.0           0.0            2.0
#
#      saturated fat (PDV)  carbohydrates (PDV)
# 721                112.0                 14.0

# %%
recipes_df.columns

# %%
recipes_df.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  n_steps  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...       11
# 1  ['30-minutes-or-less', 'time-to-make', 'course...        9
# 2  ['time-to-make', 'course', 'preparation', 'mai...        6
# 3  ['60-minutes-or-less', 'time-to-make', 'course...       11
# 4  ['weeknight', 'time-to-make', 'course', 'main-...        5
#
# ...

# %%
recipes_df.rename(columns={"minutes":"preparation_time" , "steps":"directions"}, inplace=True)
selected_columns = ['name', 'preparation_time','directions', 'ingredients', 'calories', 'total fat (PDV)', 'sugar (PDV)', 'sodium (PDV)', 'protein (PDV)', 'saturated fat (PDV)', 'carbohydrates (PDV)']
recipes_df = recipes_df[selected_columns]
recipes_df.head()
# Out:
#                                          name  preparation_time  \
# 0  arriba   baked winter squash mexican style                55
# 1            a bit different  breakfast pizza                30
# 2                   all in the kitchen  chili               130
# 3                          alouette  potatoes                45
# 4          amish  tomato ketchup  for canning               190
#
#                                           directions  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          ingredients  calories  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...      51.5
# 1  ['prepared pizza crust', 'sausage patty', 'egg...     173.4
# 2  ['ground beef', 'yellow onions', 'diced tomato...     269.8
# ...

# %%
recipes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230489 entries, 0 to 231636
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   name                 230489 non-null  object
#  1   preparation_time     230489 non-null  int64
#  2   directions           230489 non-null  object
#  3   ingredients          230489 non-null  object
#  4   calories             230489 non-null  float64
#  5   total fat (PDV)      230489 non-null  float64
#  6   sugar (PDV)          230489 non-null  float64
#  7   sodium (PDV)         230489 non-null  float64
#  8   protein (PDV)        230489 non-null  float64
#  9   saturated fat (PDV)  230489 non-null  float64
#  10  carbohydrates (PDV)  230489 non-null  float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 21.1+ MB

# %%
recipes_df.to_csv('../data/recipes/raw_unique_recipes.csv', index=False)
